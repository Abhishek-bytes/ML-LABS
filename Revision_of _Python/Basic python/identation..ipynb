# %%
#Identation
print ("Starting a loop ")
for x in [1,2,3,4,5]:
    if x % 2 ==0:
        x+=3
        print (x)
    print("one excution of loop")
print("end of loop")
# Out:
# Starting a loop
# one excution of loop
# 5
# one excution of loop
# one excution of loop
# 7
# one excution of loop
# one excution of loop
# end of loop

# %%
for i in [1,2,3,4,5]:
    if i%2==0:
        print(i)
